# %% [markdown]
# <a href="https://colab.research.google.com/github/KurniaKhaikal/Corel-CBIR/blob/main/VGG16_CBIR_FIXXX-Ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import json
import os
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.models import Model

# %%
from imutils import paths
import cv2
from sklearn.preprocessing import LabelBinarizer

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_dataset = "/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/dataset"
class_dir = ['beaches', 'bus', 'dinosaurs',
             'elephants', 'flowers', 'foods',
             'horses', 'monuments', 'mountains_and_snow','peolpe_and_villages_in_Africa'
             ]
IMAGE_SIZE = (224, 224)

# %%
# indexing file images
dataset_train = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dataset, 'training_set', class_item)
    for file in os.listdir(cur_dir):
        dataset_train.append(os.path.join(cur_dir, file))

# %%
print("train:", len(dataset_train))
# Out:
# train: 900

# %%
print("[INFO] load images Corel-Image 1k dataset...")
#  load images
train_images = []
for image_path in dataset_train:
    if ".jpg" or ".jpeg" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        train_images.append(image)
# Out:
# [INFO] load images Corel-Image 1k dataset...

# %%
# normalization
print("[INFO] normalization...")
train_x = np.array(train_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
from tensorflow.keras.applications.vgg16 import VGG16
modelVGG16 = VGG16(weights="imagenet")
model = Model(inputs=modelVGG16.input, outputs=modelVGG16.get_layer("fc1").output)
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467096/553467096 [==============================] - 14s 0us/step
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
# =================================================================
# Total params: 117,479,232
# Trainable params: 117,479,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
features = model.predict(train_x)
# Out:
# 29/29 [==============================] - 596s 21s/step

# %%
dataset_train[0]
# Out:
# '/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/dataset/training_set/beaches/113.jpg'

# %%
indexes = list(range(0, train_x.shape[0]))
features_array = [[float(x) for x in y] for y in features]
labels = [path.split("/")[9] for path in dataset_train] # karena path datanya berbeda indexing juga berbeda
data_train = {"indexes": indexes, "features": features_array, "locations": dataset_train, "labels":labels}

# %%
with open('/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/dataset/feature_extraction1.json', 'w') as f:
    json.dump(data_train, f)

# %% [markdown]
# **RETRIEVAL**

# %%
import copy
import numpy as np
import os
import json
import cv2
import sklearn.metrics as metric
from tensorflow.keras.models import Model
import pandas as pd

# %%
def euclidean(a, b):
	return np.linalg.norm(a - b)

# %%
def perform_search(query_features, indexed_train, max_results=5):
	retrieved = []
	for idx in range(0, len(indexed_train["features"])):
		distance = euclidean(query_features, indexed_train["features"][idx])
		retrieved.append((distance, idx))
	retrieved = sorted(retrieved)[:max_results]
	return retrieved

# %%
base_dataset = "/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/dataset"
class_dir = ['beaches', 'bus', 'dinosaurs',
             'elephants', 'flowers', 'foods',
             'horses', 'monuments', 'mountains_and_snow','peolpe_and_villages_in_Africa'
             ]

IMAGE_SIZE = (224, 224)

# %%
# indexing file images
dataset_test = []
for class_item in class_dir:
    cur_dir = os.path.join(base_dataset, 'test_set', class_item)
    for file in os.listdir(cur_dir):
        dataset_test.append(os.path.join(cur_dir, file))

# %%
print("len to retrieving:", len(dataset_test))
# Out:
# len to retrieving: 100

# %%
print("[INFO] load images Corel-Image 1k dataset...")
#  load images
test_images = []
for image_path in dataset_test:
    if ".jpg" or ".jpeg" in image_path:
        image = cv2.imread(image_path)
        image = cv2.resize(image, IMAGE_SIZE)
        test_images.append(image)
# Out:
# [INFO] load images Corel-Image 1k dataset...

# %%
print("[INFO] normalization...")
test_x = np.array(test_images).astype("float32") / 255.0
# Out:
# [INFO] normalization...

# %%
from tensorflow.keras.applications import VGG16
modelVGG16 = VGG16(weights="imagenet")
model = Model(inputs=modelVGG16.input, outputs=modelVGG16.get_layer("fc1").output)
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  fc1 (Dense)                 (None, 4096)              102764544
#
# =================================================================
# Total params: 117,479,232
# Trainable params: 117,479,232
# Non-trainable params: 0
# _________________________________________________________________

# %%
features = model.predict(test_x)
# Out:
# 4/4 [==============================] - 68s 15s/step

# %%
with open('/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/dataset/feature_extraction1.json') as f:
  training_indexed = json.load(f)

# %%
label_encoder = {'beaches': 0,
                 'bus': 1,
                 'dinosaurs': 2,
                 'elephants': 3,
                 'flowers': 4,
                 'foods': 5,
                 'horses': 6,
                 'monuments': 7,
                 'mountains_and_snow': 8,
                 'peolpe_and_villages_in_Africa': 9}

# %%
import statistics

query_indexes = list(range(0, test_x.shape[0]))
label_builder = list(np.unique(training_indexed["labels"]))
class_builder = {label_unique:[] for label_unique in label_builder}
recalls = copy.deepcopy(class_builder)
precisions = copy.deepcopy(class_builder)
y_pred = []
y_true = []
# loop over the testing indexes
for i in query_indexes:
    queryFeatures = features[i]
    results = perform_search(queryFeatures, training_indexed, max_results=12)
    labels_ret = [training_indexed["labels"][r[1]] for r in results]
    labels_ret_mode = statistics.mode(labels_ret)
    label_true = dataset_test[i].split("/")[9]
    label_trues = [label_true for _ in labels_ret]
    label_trues_mode = statistics.mode(label_trues)
    label_true_encode = label_encoder[label_trues_mode]
    label_pred_encode = label_encoder[labels_ret_mode]
    y_true.append(label_true_encode)
    y_pred.append(label_pred_encode)

    ## Kode dibawah tidak diperlukan karena untuk mengukur metrics diperlukan y_true dan y_pred
    # recall = metric.recall_score(label_trues, labels_ret, average='weighted')
    # precision = metric.precision_score(label_trues, labels_ret, average='weighted')
    # recalls[label_true].append(recall)
    # precisions[label_true].append(precision)

# %%
len(y_pred), len(y_true)
# Out:
# (100, 100)

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import seaborn as sns

cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(6, 4))
sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.yticks(list(label_encoder.values()), list(label_encoder.keys()), rotation=0)
plt.xticks(list(label_encoder.values()), list(label_encoder.keys()), rotation=90)
plt.show()

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.60      0.57        10
#            1       1.00      1.00      1.00        10
#            2       1.00      1.00      1.00        10
#            3       0.73      0.80      0.76        10
#            4       0.77      1.00      0.87        10
#            5       1.00      0.50      0.67        10
#            6       0.89      0.80      0.84        10
#            7       0.73      0.80      0.76        10
#            8       0.91      1.00      0.95        10
#            9       0.78      0.70      0.74        10
#
#     accuracy                           0.82       100
#    macro avg       0.83      0.82      0.82       100
# weighted avg       0.83      0.82      0.82       100

# %%
## Dosen't need to run

# print("recall values:")
# comb_recall, comb_precision = [], []
# for key in recalls.keys():
#     average_val = np.average(recalls[key])
#     print(key, average_val)
#     comb_recall.append(average_val)
# print("combined recall", np.average(comb_recall))

# print("\nprecision values:")
# for key in precisions.keys():
#     average_val = np.average(precisions[key])
#     print(key, average_val)
#     comb_precision.append(average_val)
# print("combined precision", np.average(comb_precision))

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.models import Model
import numpy as np

# See https://keras.io/api/applications/ for details

class FeatureExtractor:
    def __init__(self):
        base_model = VGG16(weights='imagenet')
        self.model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

    def extract(self, img):
        """
        Extract a deep feature from an input image
        Args:
            img: from PIL.Image.open(path) or tensorflow.keras.preprocessing.image.load_img(path)

        Returns:
            feature (np.ndarray): deep feature with the shape=(4096, )
        """
        img = img.resize((224, 224))  # VGG must take a 224x224 img as an input
        img = img.convert('RGB')  # Make sure img is color
        x = image.img_to_array(img)  # To np.array. Height x Width x Channel. dtype=float32
        x = np.expand_dims(x, axis=0)  # (H, W, C)->(1, H, W, C), where the first elem is the number of img
        x = preprocess_input(x)  # Subtracting avg values for each pixel
        feature = self.model.predict(x)[0]  # (1, 4096) -> (4096, )
        return feature / np.linalg.norm(feature)  # Normalize

# %%
from PIL import Image
# from feature-extractor import FeatureExtractor
from pathlib import Path
import numpy as np

if __name__ == '__main__':
    fe = FeatureExtractor()

    for img_path in sorted(Path("/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image").glob("*.jpg")):
        print(img_path)  # e.g., ./static/img/xxx.jpg
        feature = fe.extract(img=Image.open(img_path))
        feature_path = Path("/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/feature") / (img_path.stem + ".npy")  # e.g., ./static/feature/xxx.npy
        np.save(feature_path, feature)
# Out:
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/0.jpg
# 1/1 [==============================] - 1s 759ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/1.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/10.jpg
# 1/1 [==============================] - 1s 628ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/100.jpg
# 1/1 [==============================] - 1s 629ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/101.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/102.jpg
# 1/1 [==============================] - 1s 713ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/103.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/104.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/105.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/106.jpg
# 1/1 [==============================] - 1s 880ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/107.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/108.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/109.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/11.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/110.jpg
# 1/1 [==============================] - 1s 633ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/111.jpg
# 1/1 [==============================] - 1s 640ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/112.jpg
# 1/1 [==============================] - 1s 670ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/113.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/114.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/115.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/116.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/117.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/118.jpg
# 1/1 [==============================] - 1s 632ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/119.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/12.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/120.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/121.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/122.jpg
# 1/1 [==============================] - 1s 958ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/123.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/124.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/125.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/126.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/127.jpg
# 1/1 [==============================] - 1s 622ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/128.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/129.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/13.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/130.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/131.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/132.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/133.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/134.jpg
# 1/1 [==============================] - 1s 703ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/135.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/136.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/137.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/138.jpg
# 1/1 [==============================] - 1s 647ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/139.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/14.jpg
# 1/1 [==============================] - 1s 595ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/140.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/141.jpg
# 1/1 [==============================] - 1s 689ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/142.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/143.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/144.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/145.jpg
# 1/1 [==============================] - 1s 644ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/146.jpg
# 1/1 [==============================] - 1s 632ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/147.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/148.jpg
# 1/1 [==============================] - 1s 622ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/149.jpg
# 1/1 [==============================] - 1s 647ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/15.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/150.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/151.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/152.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/153.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/154.jpg
# 1/1 [==============================] - 1s 607ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/155.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/156.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/157.jpg
# 1/1 [==============================] - 1s 660ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/158.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/159.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/16.jpg
# 1/1 [==============================] - 1s 629ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/160.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/161.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/162.jpg
# 1/1 [==============================] - 1s 834ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/163.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/164.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/165.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/166.jpg
# 1/1 [==============================] - 1s 636ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/167.jpg
# 1/1 [==============================] - 1s 634ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/168.jpg
# 1/1 [==============================] - 1s 640ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/169.jpg
# 1/1 [==============================] - 1s 651ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/17.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/170.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/171.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/172.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/173.jpg
# 1/1 [==============================] - 1s 591ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/174.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/175.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/176.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/177.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/178.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/179.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/18.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/180.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/181.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/182.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/183.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/184.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/185.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/186.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/187.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/188.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/189.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/19.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/190.jpg
# 1/1 [==============================] - 1s 809ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/191.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/192.jpg
# 1/1 [==============================] - 1s 612ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/193.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/194.jpg
# 1/1 [==============================] - 1s 682ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/195.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/196.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/197.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/198.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/199.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/2.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/20.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/200.jpg
# 1/1 [==============================] - 1s 586ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/201.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/202.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/203.jpg
# 1/1 [==============================] - 1s 618ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/204.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/205.jpg
# 1/1 [==============================] - 1s 649ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/206.jpg
# 1/1 [==============================] - 1s 716ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/207.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/208.jpg
# 1/1 [==============================] - 1s 984ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/209.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/21.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/210.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/211.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/212.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/213.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/214.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/215.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/216.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/217.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/218.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/219.jpg
# 1/1 [==============================] - 1s 625ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/22.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/220.jpg
# 1/1 [==============================] - 1s 587ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/221.jpg
# 1/1 [==============================] - 1s 588ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/222.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/223.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/224.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/225.jpg
# 1/1 [==============================] - 1s 805ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/226.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/227.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/228.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/229.jpg
# 1/1 [==============================] - 1s 618ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/23.jpg
# 1/1 [==============================] - 1s 641ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/230.jpg
# 1/1 [==============================] - 1s 625ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/231.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/232.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/233.jpg
# 1/1 [==============================] - 1s 639ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/234.jpg
# 1/1 [==============================] - 1s 648ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/235.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/236.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/237.jpg
# 1/1 [==============================] - 1s 873ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/238.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/239.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/24.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/240.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/241.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/242.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/243.jpg
# 1/1 [==============================] - 1s 592ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/244.jpg
# 1/1 [==============================] - 1s 622ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/245.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/246.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/247.jpg
# 1/1 [==============================] - 1s 943ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/248.jpg
# 1/1 [==============================] - 1s 595ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/249.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/25.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/250.jpg
# 1/1 [==============================] - 1s 626ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/251.jpg
# 1/1 [==============================] - 1s 634ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/252.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/253.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/254.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/255.jpg
# 1/1 [==============================] - 1s 748ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/256.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/257.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/258.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/259.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/26.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/260.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/261.jpg
# 1/1 [==============================] - 1s 612ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/262.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/263.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/264.jpg
# 1/1 [==============================] - 1s 644ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/265.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/266.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/267.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/268.jpg
# 1/1 [==============================] - 1s 644ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/269.jpg
# 1/1 [==============================] - 1s 654ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/27.jpg
# 1/1 [==============================] - 1s 591ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/270.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/271.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/272.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/273.jpg
# 1/1 [==============================] - 1s 620ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/274.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/275.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/276.jpg
# 1/1 [==============================] - 1s 820ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/277.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/278.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/279.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/28.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/280.jpg
# 1/1 [==============================] - 1s 579ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/281.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/282.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/283.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/284.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/285.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/286.jpg
# 1/1 [==============================] - 1s 708ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/287.jpg
# 1/1 [==============================] - 1s 607ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/288.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/289.jpg
# 1/1 [==============================] - 1s 589ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/29.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/290.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/291.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/292.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/293.jpg
# 1/1 [==============================] - 1s 915ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/294.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/295.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/296.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/297.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/298.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/299.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/3.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/30.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/300.jpg
# 1/1 [==============================] - 1s 583ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/301.jpg
# 1/1 [==============================] - 1s 595ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/302.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/303.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/304.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/305.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/306.jpg
# 1/1 [==============================] - 1s 618ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/307.jpg
# 1/1 [==============================] - 1s 637ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/308.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/309.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/31.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/32.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/33.jpg
# 1/1 [==============================] - 1s 904ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/34.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/35.jpg
# 1/1 [==============================] - 1s 859ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/36.jpg
# 1/1 [==============================] - 1s 592ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/37.jpg
# 1/1 [==============================] - 1s 585ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/38.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/39.jpg
# 1/1 [==============================] - 1s 652ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/4.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/40.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/400.jpg
# 1/1 [==============================] - 1s 582ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/401.jpg
# 1/1 [==============================] - 1s 708ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/402.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/403.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/404.jpg
# 1/1 [==============================] - 1s 585ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/405.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/406.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/407.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/408.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/409.jpg
# 1/1 [==============================] - 1s 611ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/41.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/410.jpg
# 1/1 [==============================] - 1s 621ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/411.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/412.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/413.jpg
# 1/1 [==============================] - 1s 830ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/414.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/415.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/416.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/417.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/418.jpg
# 1/1 [==============================] - 1s 598ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/419.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/42.jpg
# 1/1 [==============================] - 1s 622ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/420.jpg
# 1/1 [==============================] - 1s 644ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/421.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/422.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/423.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/424.jpg
# 1/1 [==============================] - 1s 633ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/425.jpg
# 1/1 [==============================] - 1s 639ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/426.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/427.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/428.jpg
# 1/1 [==============================] - 1s 654ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/429.jpg
# 1/1 [==============================] - 1s 632ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/43.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/430.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/431.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/432.jpg
# 1/1 [==============================] - 1s 884ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/433.jpg
# 1/1 [==============================] - 1s 612ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/434.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/435.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/436.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/437.jpg
# 1/1 [==============================] - 1s 834ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/438.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/439.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/44.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/440.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/441.jpg
# 1/1 [==============================] - 1s 607ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/442.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/443.jpg
# 1/1 [==============================] - 1s 593ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/444.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/445.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/446.jpg
# 1/1 [==============================] - 1s 637ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/447.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/448.jpg
# 1/1 [==============================] - 1s 585ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/449.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/45.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/450.jpg
# 1/1 [==============================] - 1s 593ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/451.jpg
# 1/1 [==============================] - 1s 593ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/452.jpg
# 1/1 [==============================] - 1s 629ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/453.jpg
# 1/1 [==============================] - 1s 646ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/454.jpg
# 1/1 [==============================] - 1s 588ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/455.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/456.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/457.jpg
# 1/1 [==============================] - 1s 636ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/458.jpg
# 1/1 [==============================] - 2s 2s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/459.jpg
# 1/1 [==============================] - 2s 2s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/46.jpg
# 1/1 [==============================] - 1s 827ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/460.jpg
# 1/1 [==============================] - 1s 944ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/461.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/462.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/463.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/464.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/465.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/466.jpg
# 1/1 [==============================] - 1s 618ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/467.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/468.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/469.jpg
# 1/1 [==============================] - 1s 736ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/47.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/470.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/471.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/472.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/473.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/474.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/475.jpg
# 1/1 [==============================] - 1s 642ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/476.jpg
# 1/1 [==============================] - 1s 829ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/477.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/478.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/479.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/48.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/480.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/481.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/482.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/483.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/484.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/485.jpg
# 1/1 [==============================] - 1s 628ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/486.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/487.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/488.jpg
# 1/1 [==============================] - 1s 846ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/489.jpg
# 1/1 [==============================] - 1s 654ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/49.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/490.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/491.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/492.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/493.jpg
# 1/1 [==============================] - 1s 612ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/494.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/495.jpg
# 1/1 [==============================] - 1s 780ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/496.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/497.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/498.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/499.jpg
# 1/1 [==============================] - 1s 620ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/5.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/50.jpg
# 1/1 [==============================] - 1s 618ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/500.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/501.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/502.jpg
# 1/1 [==============================] - 1s 642ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/503.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/504.jpg
# 1/1 [==============================] - 1s 842ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/505.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/506.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/507.jpg
# 1/1 [==============================] - 1s 597ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/508.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/509.jpg
# 1/1 [==============================] - 1s 622ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/51.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/510.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/511.jpg
# 1/1 [==============================] - 1s 639ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/512.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/513.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/514.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/515.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/516.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/517.jpg
# 1/1 [==============================] - 1s 629ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/518.jpg
# 1/1 [==============================] - 1s 604ms/step
# ...
# 1/1 [==============================] - 1s 696ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/887.jpg
# 1/1 [==============================] - 1s 625ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/888.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/889.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/89.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/890.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/891.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/892.jpg
# 1/1 [==============================] - 1s 649ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/893.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/894.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/895.jpg
# 1/1 [==============================] - 1s 932ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/896.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/897.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/898.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/899.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/9.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/90.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/900.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/901.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/902.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/903.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/904.jpg
# 1/1 [==============================] - 1s 828ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/905.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/906.jpg
# 1/1 [==============================] - 1s 617ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/907.jpg
# 1/1 [==============================] - 1s 638ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/908.jpg
# 1/1 [==============================] - 1s 614ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/909.jpg
# 1/1 [==============================] - 1s 626ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/91.jpg
# 1/1 [==============================] - 1s 637ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/910.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/911.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/912.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/913.jpg
# 1/1 [==============================] - 1s 984ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/914.jpg
# 1/1 [==============================] - 1s 606ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/915.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/916.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/917.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/918.jpg
# 1/1 [==============================] - 1s 587ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/919.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/92.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/920.jpg
# 1/1 [==============================] - 1s 993ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/921.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/922.jpg
# 1/1 [==============================] - 1s 925ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/923.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/924.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/925.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/926.jpg
# 1/1 [==============================] - 1s 635ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/927.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/928.jpg
# 1/1 [==============================] - 1s 625ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/929.jpg
# 1/1 [==============================] - 1s 637ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/93.jpg
# 1/1 [==============================] - 1s 591ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/930.jpg
# 1/1 [==============================] - 1s 840ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/931.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/932.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/933.jpg
# 1/1 [==============================] - 1s 624ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/934.jpg
# 1/1 [==============================] - 1s 627ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/935.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/936.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/937.jpg
# 1/1 [==============================] - 1s 610ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/938.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/939.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/94.jpg
# 1/1 [==============================] - 1s 582ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/940.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/941.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/942.jpg
# 1/1 [==============================] - 1s 607ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/943.jpg
# 1/1 [==============================] - 1s 591ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/944.jpg
# 1/1 [==============================] - 1s 595ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/945.jpg
# 1/1 [==============================] - 1s 587ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/946.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/947.jpg
# 1/1 [==============================] - 1s 623ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/948.jpg
# 1/1 [==============================] - 1s 629ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/949.jpg
# 1/1 [==============================] - 1s 583ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/95.jpg
# 1/1 [==============================] - 1s 887ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/950.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/951.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/952.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/953.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/954.jpg
# 1/1 [==============================] - 1s 637ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/955.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/956.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/957.jpg
# 1/1 [==============================] - 1s 609ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/958.jpg
# 1/1 [==============================] - 1s 589ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/959.jpg
# 1/1 [==============================] - 1s 578ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/96.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/960.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/961.jpg
# 1/1 [==============================] - 1s 854ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/962.jpg
# 1/1 [==============================] - 1s 607ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/963.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/964.jpg
# 1/1 [==============================] - 1s 593ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/965.jpg
# 1/1 [==============================] - 1s 630ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/966.jpg
# 1/1 [==============================] - 1s 631ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/967.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/968.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/969.jpg
# 1/1 [==============================] - 1s 594ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/97.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/970.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/971.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/972.jpg
# 1/1 [==============================] - 1s 604ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/973.jpg
# 1/1 [==============================] - 1s 603ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/974.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/975.jpg
# 1/1 [==============================] - 1s 613ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/976.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/977.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/978.jpg
# 1/1 [==============================] - 1s 589ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/979.jpg
# 1/1 [==============================] - 1s 619ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/98.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/980.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/981.jpg
# 1/1 [==============================] - 1s 588ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/982.jpg
# 1/1 [==============================] - 1s 605ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/983.jpg
# 1/1 [==============================] - 1s 601ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/984.jpg
# 1/1 [==============================] - 1s 608ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/985.jpg
# 1/1 [==============================] - 1s 615ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/986.jpg
# 1/1 [==============================] - 1s 584ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/987.jpg
# 1/1 [==============================] - 1s 590ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/988.jpg
# 1/1 [==============================] - 1s 602ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/989.jpg
# 1/1 [==============================] - 1s 999ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/99.jpg
# 1/1 [==============================] - 1s 1s/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/990.jpg
# 1/1 [==============================] - 1s 923ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/991.jpg
# 1/1 [==============================] - 1s 583ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/992.jpg
# 1/1 [==============================] - 1s 589ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/993.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/994.jpg
# 1/1 [==============================] - 1s 600ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/995.jpg
# 1/1 [==============================] - 1s 596ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/996.jpg
# 1/1 [==============================] - 1s 616ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/997.jpg
# 1/1 [==============================] - 1s 599ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/998.jpg
# 1/1 [==============================] - 1s 589ms/step
# /content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/999.jpg
# 1/1 [==============================] - 1s 1s/step

# %%
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
# from feature_extractor import FeatureExtractor
from datetime import datetime
from flask import Flask, request, render_template
from pathlib import Path

# Upload
img_name = "/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image/305.jpg"
img = Image.open(img_name)

# Read image features
fe = FeatureExtractor()
features = []
img_paths = []
for feature_path in Path("/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/feature").glob("*.npy"):
    features.append(np.load(feature_path))
    img_paths.append(Path("/content/drive/MyDrive/Corel-1kNew-R2/PROJECT-TA/Corel-1kNew/image") / (feature_path.stem + ".jpg"))
features = np.array(features)

# Run Search
query = fe.extract(img)
dists = np.linalg.norm(features-query, axis=1)  # L2 distances to features
ids = np.argsort(dists)[:12]  # Top 12 results
scores = [(dists[id], img_paths[id]) for id in ids]

# len(scores)

# Visualize

import matplotlib.image as mpimg
fig=plt.figure(figsize=(8,8))
read_image = mpimg.imread(img_name)
fig.tight_layout()
plt.title("Query Image")
plt.imshow(read_image)
plt.show()

print(" ")

axes=[]
fig=plt.figure(figsize=(8,8))
for a in range(12):
    score = scores[a]
    axes.append(fig.add_subplot(5, 6, a+1))
    subplot_title=str(score[0])
    axes[-1].set_title(subplot_title)
    plt.axis('off')
    plt.imshow(Image.open(score[1]))
fig.tight_layout()
plt.show()

# max_hasil = 12
# hasil = [imgNames[index] for i,index in enumerate(rank_ID[0:max_hasil])]
# print(" ")
# fig = plt.figure(figsize=(10, 10))

# for i,im in enumerate(hasil):
#     fig.add_subplot(3, 4, i+1)
#     plt.axis('off')
#     plt.subplots_adjust(wspace=None, hspace=None)
#     img_result = mpimg.imread(base_dataset+"/"+str(im, 'utf-8'))
#     plt.title("Hasil %d" %(i+1))
#     plt.imshow(img_result)


# @app.route('/', methods=['GET', 'POST'])
# def index():
#     if request.method == 'POST':
#         file = request.files['query_img']

#         # Save query image
#         img = Image.open(file.stream)  # PIL image
#         uploaded_img_path = "static/uploaded/" + datetime.now().isoformat().replace(":", ".") + "_" + file.filename
#         img.save(uploaded_img_path)

#         # Run search
#         query = fe.extract(img)
#         dists = np.linalg.norm(features-query, axis=1)  # L2 distances to features
#         ids = np.argsort(dists)[:30]  # Top 30 results
#         scores = [(dists[id], img_paths[id]) for id in ids]

#         return render_template('index.html',
#                                query_path=uploaded_img_path,
#                                scores=scores)
#     else:
#         return render_template('index.html')


# if __name__=="__main__":
#     app.run("0.0.0.0")
# Out:
# 1/1 [==============================] - 1s 779ms/step
